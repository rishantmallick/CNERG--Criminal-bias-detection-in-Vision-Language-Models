# %%
# !pip install huggingface
# !pip install huggingface_hub
# !pip install transformers
# Out:
# Collecting huggingface
#   Downloading huggingface-0.0.1-py3-none-any.whl.metadata (2.9 kB)
# Downloading huggingface-0.0.1-py3-none-any.whl (2.5 kB)
# Installing collected packages: huggingface
# Successfully installed huggingface-0.0.1
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (1.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (3.20.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (6.0.3)
# Requirement already satisfied: shellingham in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (1.5.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.67.3)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (0.21.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub) (0.16.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer-slim->huggingface_hub) (8.3.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (5.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.3)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (1.4.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.28.1)
# Requirement already satisfied: shellingham in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.5.4)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (4.15.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer-slim->transformers) (8.3.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (0.16.0)

# %%
from datasets import Dataset, DatasetDict
import pandas as pd
df1 = pd.read_csv("Rajasthan_metadata.csv")
df2 = pd.read_csv("Rest_metadata.csv")
df1 = df1[['Name','Caste','Clustered_Caste']]
df2 = df2[['Name']]
df1['Caste'] = df1['Caste'].fillna('Unknown')
df1['Clustered_Caste'] = df1['Clustered_Caste'].fillna('Unknown')

name1 = []
caste1 = []
cluster1 = []
name2 = []
for i in range(len(df1)):
  name1.append(df1['Name'].iloc[i])
  caste1.append(df1['Caste'].iloc[i])
  cluster1.append(df1['Clustered_Caste'].iloc[i])
for i in range(len(df2)):
  name2.append(df2['Name'].iloc[i])
dict1 = {'Name':name1,'Caste':caste1}

dict2 = {'Name':name2}
train_dataset = Dataset.from_dict(dict1)
test_dataset = Dataset.from_dict(dict2)
dataset = DatasetDict({
    "train": train_dataset,
    "test": test_dataset
})

from sklearn.preprocessing import LabelEncoder
le_caste = LabelEncoder()
dataset["train"] = dataset["train"].remove_columns("Caste").add_column(
    "label_caste", le_caste.fit_transform(dataset["train"]["Caste"])
)
print(dataset)
num_labels = len(le_caste.classes_)
print(num_labels)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['Name', 'label_caste'],
#         num_rows: 5000
#     })
#     test: Dataset({
#         features: ['Name'],
#         num_rows: 666
#     })
# })
# 875

# %%
print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['Name', 'label_caste'],
#         num_rows: 5000
#     })
#     test: Dataset({
#         features: ['Name'],
#         num_rows: 666
#     })
# })

# %%
from huggingface_hub import login

login()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
tokenizer = AutoTokenizer.from_pretrained("ai4bharat/indic-bert")
def tokenize(examples):
    return tokenizer(
        examples["Name"],
        padding="max_length",
        truncation=True
    )

dataset = dataset.map(tokenize, batched=True)
model = AutoModelForSequenceClassification.from_pretrained(
    "ai4bharat/indic-bert",
    num_labels=num_labels
)
import numpy as np
# Out:
# config.json:   0%|          | 0.00/507 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/5.65M [00:00<?, ?B/s]
# Map:   0%|          | 0/5000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/666 [00:00<?, ? examples/s]
# pytorch_model.bin:   0%|          | 0.00/135M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/25 [00:00<?, ?it/s]
# AlbertForSequenceClassification LOAD REPORT from: ai4bharat/indic-bert
# Key                              | Status     |
# ---------------------------------+------------+-
# predictions.decoder.bias         | UNEXPECTED |
# sop_classifier.classifier.weight | UNEXPECTED |
# sop_classifier.classifier.bias   | UNEXPECTED |
# predictions.LayerNorm.weight     | UNEXPECTED |
# predictions.LayerNorm.bias       | UNEXPECTED |
# predictions.dense.bias           | UNEXPECTED |
# predictions.dense.weight         | UNEXPECTED |
# predictions.bias                 | UNEXPECTED |
# predictions.decoder.weight       | UNEXPECTED |
# classifier.weight                | MISSING    |
# classifier.bias                  | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.

# %%
print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['Name', 'label_caste', 'input_ids', 'attention_mask'],
#         num_rows: 5000
#     })
#     test: Dataset({
#         features: ['Name', 'input_ids', 'attention_mask'],
#         num_rows: 666
#     })
# })

# %%
# !pip install evaluate
# Out:
# Collecting evaluate
#   Downloading evaluate-0.4.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (4.0.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.0.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.32.4)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.12/dist-packages (from evaluate) (4.67.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from evaluate) (3.6.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (1.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from evaluate) (26.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (3.20.3)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (18.1.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (3.13.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (0.28.1)
# Requirement already satisfied: shellingham in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (1.5.4)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (0.21.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (2026.1.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2025.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.22.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.7.0->evaluate) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.7.0->evaluate) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.7.0->evaluate) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer-slim->huggingface-hub>=0.7.0->evaluate) (8.3.1)
# Downloading evaluate-0.4.6-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 8.3 MB/s eta 0:00:00
# model.safetensors:   0%|          | 0.00/135M [00:00<?, ?B/s]
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.6

# %%
import evaluate
metric = evaluate.load("accuracy")
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    # convert the logits to their predicted class
    predictions = np.argmax(logits, axis=-1)
    return metric.compute(predictions=predictions, references=labels)
from transformers import TrainingArguments, DataCollatorWithPadding # Re-add DataCollatorWithPadding

training_args = TrainingArguments(
    output_dir="yelp_review_classifier",
    eval_strategy="epoch",
    push_to_hub=False,
    warmup_steps=0.13,
    learning_rate = 5e-5,
    adam_beta1=0.9,
    adam_beta2=0.999,
    adam_epsilon=3e-8,
    weight_decay=0.001,
    lr_scheduler_type = "linear",
    num_train_epochs=50
)
from transformers import Trainer

split = dataset["train"].train_test_split(test_size=0.1)
train_dataset = split["train"]
eval_dataset = split["test"]
print(train_dataset)
train_dataset = train_dataset.rename_column("label_caste", "labels")
eval_dataset = eval_dataset.rename_column("label_caste", "labels")

train_dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'labels'])
eval_dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'labels'])

data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    compute_metrics=compute_metrics,
    data_collator=data_collator
)

trainer.train()

pred_results = trainer.predict(dataset["test"])
pred_labels = np.argmax(pred_results.predictions, axis=-1)
pred_categories = [le_caste.classes_[i] for i in pred_labels]
dict2["Caste"] = pred_categories
print(dict2)
# Out:
# Downloading builder script: 0.00B [00:00, ?B/s]
# Dataset({
#     features: ['Name', 'label_caste', 'input_ids', 'attention_mask'],
#     num_rows: 4500
# })
#     <div>
#
#       <progress value='28150' max='28150' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [28150/28150 15:11, Epoch 50/50]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>6.670458</td>
#       <td>5.819726</td>
#       <td>0.088000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>5.524766</td>
#       <td>5.203301</td>
#       <td>0.088000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>5.045006</td>
#       <td>5.049776</td>
#       <td>0.162000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>4.908626</td>
#       <td>5.091209</td>
#       <td>0.162000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>4.903917</td>
#       <td>4.936010</td>
#       <td>0.206000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>4.704751</td>
#       <td>4.881979</td>
#       <td>0.218000</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>4.641615</td>
#       <td>4.844753</td>
#       <td>0.218000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>4.501277</td>
#       <td>4.839772</td>
#       <td>0.214000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>4.404791</td>
#       <td>4.884697</td>
#       <td>0.222000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>4.405889</td>
#       <td>4.837823</td>
#       <td>0.202000</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>4.252132</td>
#       <td>4.817750</td>
#       <td>0.222000</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>4.214681</td>
#       <td>4.824381</td>
#       <td>0.192000</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>4.144668</td>
#       <td>4.831922</td>
#       <td>0.212000</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>4.098387</td>
#       <td>4.861590</td>
#       <td>0.230000</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>4.029898</td>
#       <td>4.906246</td>
#       <td>0.226000</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>3.853161</td>
#       <td>5.000797</td>
#       <td>0.208000</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>3.787698</td>
#       <td>5.012261</td>
#       <td>0.228000</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>3.659272</td>
#       <td>5.053489</td>
#       <td>0.230000</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>3.598641</td>
#       <td>5.185833</td>
#       <td>0.210000</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>3.518721</td>
#       <td>5.250071</td>
#       <td>0.214000</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>3.393134</td>
#       <td>5.279621</td>
#       <td>0.224000</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>3.332922</td>
#       <td>5.266426</td>
#       <td>0.222000</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>3.209332</td>
#       <td>5.271758</td>
#       <td>0.220000</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>3.015616</td>
#       <td>5.270435</td>
#       <td>0.220000</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>2.911579</td>
#       <td>5.377313</td>
#       <td>0.206000</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>2.804518</td>
#       <td>5.452763</td>
#       <td>0.178000</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>2.749942</td>
#       <td>5.436608</td>
#       <td>0.196000</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>2.645613</td>
#       <td>5.549272</td>
#       <td>0.188000</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td
AWAL SURENDRA', 'GADGIL NANDAN PRABHAKAR', 'BARUAH PARESH', 'SHAIKH SHAKEEL', 'SHAIKH ANIS', 'KASKAR DAWOOD IBRAHIM', 'SIVARAMA KURUP SUKUMARAN', 'VISHWANATHA SHETTY', 'SINGH GURUDEV', 'PREM SETHI', 'ANSARI TAHER', 'MOHD YUSUF SHAH', 'SAYED ARIF', 'DOSA MOHAMED AHMED', 'BEDI SURENDER SINGH', 'CHANDOK HARLEEN KAUR', 'NAUSHA KADEEJATH', 'STANLY VARGHESE BHUVANESWARI', 'EDADAN OMANA', 'ABDUL ASIF ABDUL SADIK', 'ABDUL GAFFAR ABDUL KADAR', 'ABDUL KHAN AYUB KHAN', 'Abdul Rafique Abdul Kabir', 'ABDUL SAJID ABDUL SAMAR', 'ABDUL SALIM ALIAS BADSHAHA ABDUL SALAM', 'ABDUL SHAKIR ALIAS ABDUL RAZAK', 'ABDUL WAJID ABDUL KHALID', 'ABDUL WASIM ABDUL SALAM', 'ABHISHEK VIVEK DESHMUKH', 'AJAY ARUN JUNGHARE', 'AJAY PRAKASH DABHADE', 'AKASH HARIBHAU PARTEKI', 'Akash Ramesh Wankhade', 'AKHILESH JAYANTILAL AADTIYA', 'Akshay Alias Shirish Shivdatta Mate', 'AKSHAY SURESH CHARHATE', 'AMAR ...

# %%
def tokenize(examples):
    return tokenizer(
        examples["Name"],
        padding="max_length",   # or padding=True for dynamic padding
        truncation=True
    )

test_dataset = dataset["test"].map(tokenize, batched=True)
pred_results = trainer.predict(test_dataset)
pred_labels = np.argmax(pred_results.predictions, axis=-1)
pred_categories = [le_caste.classes_[i] for i in pred_labels]
dict2["Caste"] = pred_categories
print(dict2['Name'])
print(dict2['Caste'])
# Out:
# Map:   0%|          | 0/666 [00:00<?, ? examples/s]
# ['ABHAY', 'PANCHAL MANOJ ', 'GONSALVES SUNNY', 'AMRIT', 'BAISOYA RISHABH', 'GIRI HEMANT', 'KADIAN YOGESH', 'SINGH HARBHEJ', 'SINGH JOGA', 'SHARMA SACHIN', 'BAJAJ RITIK', 'SINGH BARJINDER', 'KUMAR ANIL', 'PATEL PRITESH MUKESHBHAI', 'JAIN HARSHIT BABULAL', 'SINGH VIKRAMJEET', 'SANGWAN KAPIL', 'SINGH SATINDERJEET', 'SANDHU HARWINDER SINGH', 'SINGH RANDEEP', 'KOLANJA MOHAMMAD RAFEEQ', 'PURUSHAN SUDHEESH KUMAR', 'HAIDER SYED MUHAMMAD ARSHIYAN', 'NANAVATI ADITYA', 'SINGH GURJINDER', 'GUPTA VIKASH', 'SANDHU SHAMINDER SINGH', 'RAIJADA KAVALJITSINH MAHENDRASINH', 'SINGH HARSAHIB', 'ANGOM SANATOMBA SINGH', 'PUKHRAMBAM SAMANANDA SINGH', 'KSHETRIMAYUM BROJEN SINGH', 'TAKHELAMBAM RAGHU', 'THOKCHOM GANDHI SINGH', 'SULTAN AYAZ MOHAMMED', 'ARMAR MOHAMMAD SHAFI', 'SINGH KARANVIR', 'SINGH AVTAR', 'SINGH HARMEET', 'RANPARIYA JAYSUKH', 'SINGH JANG
OL PANDIT MOHD', 'NARENGBAM MARIJIT SINGH', 'VENKATA PRAVEEN KUMAR RAJULAPATI', 'NICOL TAMANG', 'JAGDISHBHAI PUNJIRAM', 'GHORI MOHAMMED FARHATULLAH', 'PATEL NATUBHAI SATABHAI', 'PATEL DILIPBHAI BABUBHAI', 'BATRA DAMINDER SINGH', 'SHANKARAN RAVI', 'BANGER JASWINDER SINGH', 'SYED ALMAS MAHARAJ', 'HANIF TIGER', 'AGRAWAL SURENDRA', 'GADGIL NANDAN PRABHAKAR', 'BARUAH PARESH', 'SHAIKH SHAKEEL', 'SHAIKH ANIS', 'KASKAR DAWOOD IBRAHIM', 'SIVARAMA KURUP SUKUMARAN', 'VISHWANATHA SHETTY', 'SINGH GURUDEV', 'PREM SETHI', 'ANSARI TAHER', 'MOHD YUSUF SHAH', 'SAYED ARIF', 'DOSA MOHAMED AHMED', 'BEDI SURENDER SINGH', 'CHANDOK HARLEEN KAUR', 'NAUSHA KADEEJATH', 'STANLY VARGHESE BHUVANESWARI', 'EDADAN OMANA', 'ABDUL ASIF ABDUL SADIK', 'ABDUL GAFFAR ABDUL KADAR', 'ABDUL KHAN AYUB KHAN', 'Abdul Rafique Abdul Kabir', 'ABDUL SAJID ABDUL SAMAR', 'ABDUL SALIM ALIAS BADSHAHA ABDUL SALAM', 'ABDUL SHAKIR ALIAS ABDUL RAZAK', 'ABDUL WAJID ABDUL KHALID', 'ABDUL WASIM ABDUL SALAM', 'ABHISHEK VIVEK DESHMUKH', 'AJAY ARUN JUNGHARE', 'AJAY PRAKASH DABHADE', 'AKASH HARIBHAU PARTEKI', 'Akash Ramesh Wankhade', 'AKHILESH JAYANTILAL AADTIYA', 'Akshay Alias Shirish Shivdatta Mate', 'AKSHAY SURESH CHARHATE', 'AMAR ARVIND B ...
# [np.str_('MALI'), np.str_('MEENA'), np.str_('VALMIKI'), np.str_('KANJAR'), np.str_('MEENA'), np.str_('MAHAJAN'), np.str_('NAYAK'), np.str_('RAISIKH'), np.str_('RAISIKH'), np.str_('meena'), np.str_('mev'), np.str_('Jat sikh'), np.str_('MEENA'), np.str_('JAIN'), np.str_('BRAHMAN'), np.str_('RAJPOOT'), np.str_('MALI'), np.str_('jat'), np.str_('RAISIKH'), np.str_('RAJPUT'), np.str_('musalman'), np.str_('JAAT'), np.str_('MUSALMAN'), np.str_('KHATIK'), np.str_('JATSIKH'), np.str_('Mahajan'), np.str_('meena'), np.str_('PANJABI'), np.str_('RAJPUT'), np.str_('RAJPUT'), np.str_('JAT'), np.str_('RAJPUT'), np.str_('NAYAK'), np.str_('RAJPUT'), np.str_('MUSLIM'), np.str_('MUSLIM'), np.str_('RAJPUT'), np.str_('GURJAR'), np.str_('JATSIKH'), np.str_('JAAT'), np.str_('RAJPUT'), np.str_('JATSIKH'), np.str_('MOMDAN'), np.str_('jat'), np.str_('RAJPUT'), np.str_('KANJAR'), np.str_('Rajput'), np.str_('MEV'), np.str_('muslim'), np.str_('MUSALMAN'), np.str_('SONI'), np.str_('PATHAN MUSALMAN'), np.str_('musalman'), np.str_('MUSALMAN'), np.str_('SINDHI'), np.str_('MUSLIM'), np.str_('musalman'), np.str_('MUSLIM'), np.str_('muslim'), np.str_('muslim'), np.str_('BRAHMAN'), np.str_('RAJPUT'), np.str_('MUSALMAN'), np.str_('jat'), np.str_('SONI'), np.str_('muslim'), np.str_('MUSLIM'), np.str_('BRAHMAN'), np.str_('RAYSIKH'), np.str_('MUSLIM'), np.str_('musalman'), np.str_('JAIN'), np.str_('KUMAWAT'), np.str_('muslim'), np.str_('muslim'), np.str_('RAJPUT'), np.str_('RAJPUT'), np.str_('PATHAN MUSALMAN'), np.str_('BRAHAMIN'), np.str_('ARODA'), np.str_('RAJPUT'), np.str_('JAT'), np.str_('DESWALI MUSALMAN'), np.str_('RAJPUT'), np.str_('SONI'), np.str_('MUSLMAN'), np.str_('MAHAJAN'), np.str_('MUSALMAN'), np.str_('MUSLIM'), np.str_('MUSLMAN'), np.str_('balai'), np.str_('AHIR'), np.str_('MUSALMAN'), np.str_('muslim'), np.str_('HARIJAN'), np.str_('mali'), np.str_('MOMDAN'), np.str_('GOSWAMI'), np.str_('BISHNOI'), np.str_('JAAT'), np.str_('HARIJAN'), np.str_('muslim'), np.str_('RAJPUT'), np.str_('ARORA'), np.str_('muslim'), np.str_('MAHAJAN'), np.str_('musalman'), np.str_('JAIN'), np.str_('JAAT'), np.str_('MOMDAN'), np.str_('MUSLMAN'), np.str_('RAJPOOT'), np.str_('RAYSIKH'), np.str_('BAIRWA'), np.str_('muslim'), np.str_('MAHAJAN'), np.str_('RAJPUT'), np.str_('MUSALMAN'), np.str_('HARIJAN'), np.str_('MUSLIM'), np.str_('SHARMA'), np.str_('Muslman'), np.str_('JAT SIKH'), np.str_('musalman'), np.str_('RAWAT'), np.str_('RAJPOOT'), np.str_('DESWALI MUSALMAN'), np.str_('VALMIKI'), np.str_('MUSLMAN'), np.str_('JATSIKH'), np.str_('Unknown'), np.str_('MUSLMAN'), np.str_('MUSALMAN'), np.str_('MUSALMAN'), np.str_('RAJPUT'), np.str_('SONI'), np.str_('JAIN'), np.str_('JAT'), np.str_('musalman'), np.str_('sargara'), np.str_('SWAMI'), np.str_('RAJPUT'), np.str_('NAYAK'), np.str_('RAYSIKH'), np.str_('MUSALMAN'), np.str_('MUSALMAN'), np.str_('KHATIK'), np.str_('ARORA'), np.str_('MUSALMAN'), np.str_('PATHAN MUSALMAN'), np.str_('musalman'), np.str_('MUSLMAN'), np.str_('JAAT'), np.str_('SHARMA'), np.str_('RAYSIKH'), np.str_('KHATIK'), np.str_('MUSALMAN'), np.str_('musalman'), np.str_('MUSLIM'), np.str_('PATHAN MUSALMAN'), np.str_('RAJPOOT'), np.str_('JAIN'), np.str_('Unknown'), np.str_('MOMDAN'), np.str_('Musalman'), np.str_('MUSLIM'), np.str_('MUSLMAN'), np.str_('PATHAN MUSALMAN'), np.str_('MUSLIM'), np.str_('PATHAN MUSALMAN'), np.str_('MUSLIM'), np.str_('muslim'), np.str_('MUSLIM'), np.str_('muslim'), np.str_('ARORA'), np.str_('BRAHMAN'), np.str_('BRAHMAN'), np.str_('NAYAK'), np.str_('Bishnoi'), np.str_('SONI'), np.str_('BAIRWA'), np.str_('ARORA'), np.str_('MALI'), np.str_('mali'), np.str_('MALI'), np.str_('BRAHMAN'), np.str_('DAROGA'), np.str_('BAIRWA'), np.str_('SONI'), np.str_('BAIRWA'), np.str_('BRAHMAN'), np.str_('BRAHMAN'), np.str_('SONI'), np.str_('muslim'), np.str_('muslim'), np.str_('MUSALMAN'), np.str_('AHIR'), np.str_('BRAHMAN'), np.str_('ARODA'), np.str_('BRAHAMAN'), np.str_('BAIRWA'), np.str_('musalman'), np.str_('MUSALMAN'), np.str_('Bishnoi'), np.str_('MUSLMAN'), np.str_('B ...

# %%
print(cluster1)
# Out:
# ['sc/st', 'unknown', 'unknown', 'unknown', 'obc', 'unknown', 'unknown', 'muslim', 'muslim', 'muslim', 'sc/st', 'obc', 'obc', 'obc', 'muslim', 'obc', 'obc', 'sc/st', 'sc/st', 'general', 'obc', 'obc', 'muslim', 'general', 'obc', 'general', 'obc', 'sc/st', 'muslim', 'obc', 'unknown', 'obc', 'muslim', 'general', 'sc/st', 'muslim', 'obc', 'muslim', 'sc/st', 'unknown', 'sc/st', 'unknown', 'sc/st', 'sc/st', 'obc', 'general', 'unknown', 'general', 'sc/st', 'obc', 'general', 'obc', 'muslim', 'obc', 'muslim', 'obc', 'muslim', 'general', 'unknown', 'unknown', 'obc', 'general', 'sc/st', 'muslim', 'muslim', 'general', 'obc', 'unknown', 'unknown', 'muslim', 'sc/st', 'general', 'obc', 'general', 'obc', 'sc/st', 'sc/st', 'general', 'sc/st', 'general', 'obc', 'sc/st', 'obc', 'obc', 'general', 'obc', 'obc', 'general', 'sc/st', 'sc/st', 'unknown', 'sc/st', 'unknown', 'obc', 'obc', 'unknown', 'obc', 'obc', 'obc', 'obc', 'muslim', 'unknown', 'unknown', 'unknown', 'obc', 'muslim', 'sc/st', 'muslim', 'obc', 'sc/st', 'sc/st', 'general', 'muslim', 'unknown', 'unknown', 'obc', 'sc/st', 'general', 'obc', 'unknown', 'obc', 'muslim', 'sc/st', 'sc/st', 'unknown', 'obc', 'obc', 'muslim', 'muslim', 'unknown', 'sc/st', 'unknown', 'sc/st', 'general', 'unknown', 'muslim', 'unknown', 'muslim', 'unknown', 'unknown', 'unknown', 'obc', 'sc/st', 'sc/st', 'obc', 'unknown', 'unknown', 'obc', 'sc/st', 'obc', 'muslim', 'sc/st', 'obc', 'muslim', 'obc', 'general', 'unknown', 'unknown', 'unknown', 'sc/st', 'unknown', 'sc/st', 'muslim', 'unknown', 'general', 'obc', 'general', 'muslim', 'general', 'muslim', 'general', 'obc', 'general', 'sc/st', 'general', 'unknown', 'sc/st', 'unknown', 'sc/st', 'obc', 'sc/st', 'muslim', 'unknown', 'sc/st', 'muslim', 'unknown', 'general', 'muslim', 'muslim', 'unknown', 'obc', 'general', 'obc', 'muslim', 'obc', 'muslim', 'obc', 'muslim', 'muslim', 'unknown', 'muslim', 'unknown', 'sc/st', 'obc', 'sc/st', 'muslim', 'sc/st', 'obc', 'sc/st', 'obc', 'sc/st', 'sc/st', 'muslim', 'sc/st', 'sc/st', 'muslim', 'general', 'sc/st', 'obc', 'unknown', 'unknown', 'sc/st', 'general', 'unknown', 'obc', 'muslim', 'unknown', 'general', 'unknown', 'obc', 'sc/st', 'obc', 'unknown', 'obc', 'muslim', 'obc', 'obc', 'obc', 'general', 'general', 'obc', 'sc/st', 'general', 'muslim', 'obc', 'unknown', 'general', 'obc', 'general', 'obc', 'muslim', 'sc/st', 'obc', 'obc', 'unknown', 'unknown', 'general', 'obc', 'obc', 'unknown', 'sc/st', 'unknown', 'sc/st', 'unknown', 'sc/st', 'obc', 'sc/st', 'general', 'unknown', 'unknown', 'general', 'obc', 'unknown', 'muslim', 'sc/st', 'muslim', 'unknown', 'unknown', 'unknown', 'general', 'sc/st', 'muslim', 'sc/st', 'muslim', 'obc', 'sc/st', 'muslim', 'unknown', 'unknown', 'obc', 'general', 'obc', 'unknown', 'unknown', 'sc/st', 'sc/st', 'unknown', 'muslim', 'general', 'unknown', 'muslim', 'unknown', 'general', 'obc', 'unknown', 'general', 'muslim', 'obc', 'sc/st', 'unknown', 'general', 'sc/st', 'obc', 'unknown', 'general', 'obc', 'unknown', 'general', 'obc', 'unknown', 'general', 'general', 'obc', 'sc/st', 'sc/st', 'obc', 'muslim', 'obc', 'unknown', 'unknown', 'unknown', 'unknown', 'general', 'unknown', 'unknown', 'general', 'obc', 'obc', 'sc/st', 'sc/st', 'unknown', 'muslim', 'sc/st', 'unknown', 'obc', 'obc', 'sc/st', 'muslim', 'obc', 'obc', 'obc', 'muslim', 'sc/st', 'unknown', 'obc', 'sc/st', 'general', 'sc/st', 'muslim', 'obc', 'general', 'sc/st', 'sc/st', 'unknown', 'sc/st', 'general', 'sc/st', 'unknown', 'muslim', 'muslim', 'general', 'general', 'sc/st', 'unknown', 'sc/st', 'muslim', 'unknown', 'unknown', 'obc', 'unknown', 'unknown', 'unknown', 'sc/st', 'general', 'general', 'unknown', 'sc/st', 'muslim', 'general', 'unknown', 'sc/st', 'general', 'sc/st', 'sc/st', 'general', 'unknown', 'general', 'general', 'unknown', 'sc/st', 'sc/st', 'obc', 'sc/st', 'unknown', 'general', 'obc', 'sc/st', 'sc/st', 'general', 'unknown', 'general', 'unknown', 'obc', 'obc', 'obc', 'muslim', 'obc', 'obc', 'muslim', 'general', 'unknown', 'general', 'obc',  ...

# %%
dict3 = {'Name':name1,'Cluster_caste':cluster1}
dict2 = {'Name':name2}
train_dataset = Dataset.from_dict(dict3)
test_dataset = Dataset.from_dict(dict2)
dataset1 = DatasetDict({
    "train": train_dataset,
    "test": test_dataset
})

from sklearn.preprocessing import LabelEncoder
le_cluster = LabelEncoder()
dataset1["train"] = dataset1["train"].add_column(
    "label_caste", le_cluster.fit_transform(dataset1["train"]["Cluster_caste"])
).remove_columns("Cluster_caste")
print(dataset1)
num_labels1 = len(le_cluster.classes_)
print(num_labels1)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['Name', 'label_caste'],
#         num_rows: 5000
#     })
#     test: Dataset({
#         features: ['Name'],
#         num_rows: 666
#     })
# })
# 5

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
tokenizer = AutoTokenizer.from_pretrained("ai4bharat/indic-bert")
def tokenize(examples):
    return tokenizer(
        examples["Name"],
        padding="max_length",
        truncation=True
    )

dataset1 = dataset1.map(tokenize, batched=True)
model = AutoModelForSequenceClassification.from_pretrained(
    "ai4bharat/indic-bert",
    num_labels=num_labels1
)
import numpy as np
# Out:
# Map:   0%|          | 0/5000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/666 [00:00<?, ? examples/s]
# Loading weights:   0%|          | 0/25 [00:00<?, ?it/s]
# AlbertForSequenceClassification LOAD REPORT from: ai4bharat/indic-bert
# Key                              | Status     |
# ---------------------------------+------------+-
# predictions.decoder.bias         | UNEXPECTED |
# sop_classifier.classifier.weight | UNEXPECTED |
# sop_classifier.classifier.bias   | UNEXPECTED |
# predictions.LayerNorm.weight     | UNEXPECTED |
# predictions.LayerNorm.bias       | UNEXPECTED |
# predictions.dense.bias           | UNEXPECTED |
# predictions.dense.weight         | UNEXPECTED |
# predictions.bias                 | UNEXPECTED |
# predictions.decoder.weight       | UNEXPECTED |
# classifier.weight                | MISSING    |
# classifier.bias                  | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.

# %%
print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['Name', 'label_caste', 'input_ids', 'attention_mask'],
#         num_rows: 5000
#     })
#     test: Dataset({
#         features: ['Name', 'input_ids', 'attention_mask'],
#         num_rows: 666
#     })
# })

# %%
import evaluate
metric = evaluate.load("accuracy")
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    # convert the logits to their predicted class
    predictions = np.argmax(logits, axis=-1)
    return metric.compute(predictions=predictions, references=labels)
from transformers import TrainingArguments, DataCollatorWithPadding # Re-add DataCollatorWithPadding

training_args = TrainingArguments(
    output_dir="yelp_review_classifiersed",
    eval_strategy="epoch",
    push_to_hub=False,
    warmup_steps=0.13,
    learning_rate = 5e-5,
    adam_beta1=0.9,
    adam_beta2=0.999,
    adam_epsilon=3e-8,
    weight_decay=0.001,
    lr_scheduler_type = "linear",
    num_train_epochs=50
)
from transformers import Trainer

split = dataset1["train"].train_test_split(test_size=0.1)
train_dataset = split["train"]
eval_dataset = split["test"]
print(train_dataset)
train_dataset = train_dataset.rename_column("label_caste", "labels")
eval_dataset = eval_dataset.rename_column("label_caste", "labels")

train_dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'labels'])
eval_dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'labels'])

data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    compute_metrics=compute_metrics,
    data_collator=data_collator
)

trainer.train()
# Out:
# Dataset({
#     features: ['Name', 'label_caste', 'input_ids', 'attention_mask'],
#     num_rows: 4500
# })
#     <div>
#
#       <progress value='28150' max='28150' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [28150/28150 15:24, Epoch 50/50]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.591388</td>
#       <td>1.348788</td>
#       <td>0.372000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.295231</td>
#       <td>1.288689</td>
#       <td>0.414000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.210892</td>
#       <td>1.190617</td>
#       <td>0.480000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.160429</td>
#       <td>1.186389</td>
#       <td>0.498000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.136459</td>
#       <td>1.180765</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.106274</td>
#       <td>1.203605</td>
#       <td>0.446000</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.085818</td>
#       <td>1.202190</td>
#       <td>0.478000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.017634</td>
#       <td>1.271417</td>
#       <td>0.492000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.928835</td>
#       <td>1.237266</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.855765</td>
#       <td>1.377575</td>
#       <td>0.474000</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.782574</td>
#       <td>1.485417</td>
#       <td>0.464000</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.715413</td>
#       <td>1.474552</td>
#       <td>0.472000</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.660308</td>
#       <td>1.713925</td>
#       <td>0.472000</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.602194</td>
#       <td>2.026028</td>
#       <td>0.478000</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.539278</td>
#       <td>1.869550</td>
#       <td>0.476000</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.479905</td>
#       <td>2.284822</td>
#       <td>0.470000</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.455655</td>
#       <td>2.196274</td>
#       <td>0.496000</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0
AKKAR', 'SUKHMINDER SINGH BAINS BHOLA', 'DEEPAK MANIKAN', 'KHAN GULAM NABI', 'DAR MANZOOR AHMAD', 'MAQBOOL PANDIT MOHD', 'NARENGBAM MARIJIT SINGH', 'VENKATA PRAVEEN KUMAR RAJULAPATI', 'NICOL TAMANG', 'JAGDISHBHAI PUNJIRAM', 'GHORI MOHAMMED FARHATULLAH', 'PATEL NATUBHAI SATABHAI', 'PATEL DILIPBHAI BABUBHAI', 'BATRA DAMINDER SINGH', 'SHANKARAN RAVI', 'BANGER JASWINDER SINGH', 'SYED ALMAS MAHARAJ', 'HANIF TIGER', 'AGRAWAL SURENDRA', 'GADGIL NANDAN PRABHAKAR', 'BARUAH PARESH', 'SHAIKH SHAKEEL', 'SHAIKH ANIS', 'KASKAR DAWOOD IBRAHIM', 'SIVARAMA KURUP SUKUMARAN', 'VISHWANATHA SHETTY', 'SINGH GURUDEV', 'PREM SETHI', 'ANSARI TAHER', 'MOHD YUSUF SHAH', 'SAYED ARIF', 'DOSA MOHAMED AHMED', 'BEDI SURENDER SINGH', 'CHANDOK HARLEEN KAUR', 'NAUSHA KADEEJATH', 'STANLY VARGHESE BHUVANESWARI', 'EDADAN OMANA', 'ABDUL ASIF ABDUL SADIK', 'ABDUL GAFFAR ABDUL KADAR', 'ABDUL KHAN AYUB KHAN', 'Abdul Rafique Abdul Kabir', 'ABDUL SAJID ABDUL SAMAR', 'ABDUL SALIM ALIAS BADSHAHA ABDUL SALAM', 'ABDUL SHAKIR ALIAS ABDUL RAZAK', 'ABDUL WAJID ABDUL KHALID', 'ABDUL WASIM ABDUL SALAM', 'ABHISHEK VIVEK DESHMUKH', 'AJAY ARUN JUNGHARE', 'AJAY PRAKASH DABHADE', 'AKASH HARIBHAU PARTEKI', 'Akash Ramesh Wankhade', 'AKHILESH JAYANTILAL AADTIYA', 'Akshay Alias Shirish Shivdatta Mate', 'AKSHAY SURESH CHARHATE', 'AMAR ...

# %%
pred_results = trainer.predict(dataset["test"])
pred_labels = np.argmax(pred_results.predictions, axis=-1)
pred_categories = [le_cluster.classes_[i] for i in pred_labels]
dict2["Cluster"] = pred_categories
print(dict2['Name'])
print(dict2['Cluster'])
# Out:
# ['ABHAY', 'PANCHAL MANOJ ', 'GONSALVES SUNNY', 'AMRIT', 'BAISOYA RISHABH', 'GIRI HEMANT', 'KADIAN YOGESH', 'SINGH HARBHEJ', 'SINGH JOGA', 'SHARMA SACHIN', 'BAJAJ RITIK', 'SINGH BARJINDER', 'KUMAR ANIL', 'PATEL PRITESH MUKESHBHAI', 'JAIN HARSHIT BABULAL', 'SINGH VIKRAMJEET', 'SANGWAN KAPIL', 'SINGH SATINDERJEET', 'SANDHU HARWINDER SINGH', 'SINGH RANDEEP', 'KOLANJA MOHAMMAD RAFEEQ', 'PURUSHAN SUDHEESH KUMAR', 'HAIDER SYED MUHAMMAD ARSHIYAN', 'NANAVATI ADITYA', 'SINGH GURJINDER', 'GUPTA VIKASH', 'SANDHU SHAMINDER SINGH', 'RAIJADA KAVALJITSINH MAHENDRASINH', 'SINGH HARSAHI
'CHANDOK SURENDER SINGH', 'SHEIK DAWOOD SHAHUL HAMEED', 'KSHETRIMAYUM NOYON SINGH', 'NAMOIJAM OKENDRO SINGH', 'SUMI NIKI', 'BANGARD NAVAL KISHORE', 'SIDDIQ ABUBAKKAR', 'SUKHMINDER SINGH BAINS BHOLA', 'DEEPAK MANIKAN', 'KHAN GULAM NABI', 'DAR MANZOOR AHMAD', 'MAQBOOL PANDIT MOHD', 'NARENGBAM MARIJIT SINGH', 'VENKATA PRAVEEN KUMAR RAJULAPATI', 'NICOL TAMANG', 'JAGDISHBHAI PUNJIRAM', 'GHORI MOHAMMED FARHATULLAH', 'PATEL NATUBHAI SATABHAI', 'PATEL DILIPBHAI BABUBHAI', 'BATRA DAMINDER SINGH', 'SHANKARAN RAVI', 'BANGER JASWINDER SINGH', 'SYED ALMAS MAHARAJ', 'HANIF TIGER', 'AGRAWAL SURENDRA', 'GADGIL NANDAN PRABHAKAR', 'BARUAH PARESH', 'SHAIKH SHAKEEL', 'SHAIKH ANIS', 'KASKAR DAWOOD IBRAHIM', 'SIVARAMA KURUP SUKUMARAN', 'VISHWANATHA SHETTY', 'SINGH GURUDEV', 'PREM SETHI', 'ANSARI TAHER', 'MOHD YUSUF SHAH', 'SAYED ARIF', 'DOSA MOHAMED AHMED', 'BEDI SURENDER SINGH', 'CHANDOK HARLEEN KAUR', 'NAUSHA KADEEJATH', 'STANLY VARGHESE BHUVANESWARI', 'EDADAN OMANA', 'ABDUL ASIF ABDUL SADIK', 'ABDUL GAFFAR ABDUL KADAR', 'ABDUL KHAN AYUB KHAN', 'Abdul Rafique Abdul Kabir', 'ABDUL SAJID ABDUL SAMAR', 'ABDUL SALIM ALIAS BADSHAHA ABDUL SALAM', 'ABDUL SHAKIR ALIAS ABDUL RAZAK', 'ABDUL WAJID ABDUL KHALID', 'ABDUL WASIM ABDUL SALAM', 'ABHISHEK VIVEK DESHMUKH', 'AJAY ARUN JUNGHARE', 'AJAY PRAKASH DABHADE', 'AKASH HARIBHAU PARTEKI', 'Akash Ramesh Wankhade', 'AKHILESH JAYANTILAL AADTIYA', 'Akshay Alias Shirish Shivdatta Mate', 'AKSHAY SURESH CHARHATE', 'AMAR ARVIND B ...
# [np.str_('sc/st'), np.str_('sc/st'), np.str_('sc/st'), np.str_('unknown'), np.str_('unknown'), np.str_('sc/st'), np.str_('unknown'), np.str_('general'), np.str_('general'), np.str_('unknown'), np.str_('muslim'), np.str_('unknown'), np.str_('unknown'), np.str_('general'), np.str_('general'), np.str_('unknown'), np.str_('obc'), np.str_('obc'), np.str_('general'), np.str_('obc'), np.str_('muslim'), np.str_('general'), np.str_('muslim'), np.str_('sc/st'), np.str_('unknown'), np.str_('unknown'), np.str_('obc'), np.str_('general'), np.str_('general'), np.str_('general'), np.str_('general'), np.str_('general'), np.str_('unknown'), np.str_('general'), np.str_('muslim'), np.str_('muslim'), np.str_('obc'), np.str_('general'), np.str_('unknown'), np.str_('obc'), np.str_('general'), np.str_('obc'), np.str_('muslim'), np.str_('obc'), np.str_('unknown'), np.str_('unknown'), np.str_('muslim'), np.str_('muslim'), np.str_('muslim'), np.str_('unknown'), np.str_('unknown'), np.str_('muslim'), np.str_('muslim'), np.str_('unknown'), np.str_('obc'), np.str_('muslim'), np.str_('muslim'), np.str_('muslim'), np.str_('muslim'), np.str_('muslim'), np.str_('sc/st'), np.str_('obc'), np.str_('muslim'), np.str_('obc'), np.str_('obc'), np.str_('muslim'), np.str_('muslim'), np.str_('unknown'), np.str_('obc'), np.str_('muslim'), np.str_('muslim'), np.str_('unknown'), np.str_('general'), np.str_('muslim'), np.str_('muslim'), np.str_('unknown'), np.str_('general'), np.str_('muslim'), np.str_('obc'), np.str_('unknown'), np.str_('general'), np.str_('sc/st'), np.str_('unknown'), np.str_('general'), np.str_('general'), np.str_('muslim'), np.str_('unknown'), np.str_('muslim'), np.str_('muslim'), np.str_('muslim'), np.str_('general'), np.str_('unknown'), np.str_('muslim'), np.str_('muslim'), np.str_('sc/st'), np.str_('unknown'), np.str_('sc/st'), np.str_('unknown'), np.str_('obc'), np.str_('obc'), np.str_('unknown'), np.str_('muslim'), np.str_('obc'), np.str_('obc'), np.str_('muslim'), np.str_('unknown'), np.str_('muslim'), np.str_('unknown'), np.str_('sc/st'), np.str_('unknown'), np.str_('muslim'), np.str_('general'), np.str_('general'), np.str_('obc'), np.str_('muslim'), np.str_('unknown'), np.str_('obc'), np.str_('muslim'), np.str_('general'), np.str_('muslim'), np.str_('unknown'), np.str_('muslim'), np.str_('general'), np.str_('muslim'), np.str_('general'), np.str_('general'), np.str_('unknown'), np.str_('general'), np.str_('muslim'), np.str_('obc'), np.str_('unknown'), np.str_('muslim'), np.str_('muslim'), np.str_('muslim'), np.str_('general'), np.str_('obc'), np.str_('unknown'), np.str_('obc'), np.str_('muslim'), np.str_('obc'), np.str_('obc'), np.str_('general'), np.str_('sc/st'), np.str_('unknown'), np.str_('unknown'), np.str_('muslim'), np.str_('unknown'), np.str_('obc'), np.str_('muslim'), np.str_('muslim'), np.str_('muslim'), np.str_('muslim'), np.str_('general'), np.str_('unknown'), np.str_('obc'), np.str_('general'), np.str_('muslim'), np.str_('muslim'), np.str_('muslim'), np.str_('muslim'), np.str_('general'), np.str_('general'), np.str_('general'), np.str_('general'), np.str_('unknown'), np.str_('muslim'), np.str_('muslim'), np.str_('muslim'), np.str_('muslim'), np.str_('unknown'), np.str_('muslim'), np.str_('muslim'), np.str_('unknown'), np.str_('muslim'), np.str_('general'), np.str_('general'), np.str_('general'), np.str_('obc'), np.str_('obc'), np.str_('unknown'), np.str_('obc'), np.str_('unknown'), np.str_('obc'), np.str_('obc'), np.str_('unknown'), np.str_('general'), np.str_('general'), np.str_('unknown'), np.str_('obc'), np.str_('general'), np.str_('obc'), np.str_('obc'), np.str_('unknown'), np.str_('muslim'), np.str_('muslim'), np.str_('muslim'), np.str_('obc'), np.str_('obc'), np.str_('obc'), np.str_('obc'), np.str_('obc'), np.str_('muslim'), np.str_('unknown'), np.str_('unknown'), np.str_('muslim'), np.str_('general'), np.str_('muslim'), np.str_('unknown'), np.str_('general'), np.str_('general'), np.str_('obc'), np.str_('general'), np.str_('un ...
